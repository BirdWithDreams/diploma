# %%
import os
import random
from itertools import product
from pathlib import Path

import fire
import jiwer
import librosa
import numpy as np
import pandas as pd
import torch
import torchaudio
import tqdm

import transformers
from huggingface_hub import hf_hub_download
from loguru import logger
from pydub import AudioSegment
from transformers import pipeline
# Out:
# /root/miniconda3/envs/diploma_env/lib/python3.10/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
device = 'cuda'

# %%
ecapa2_file = hf_hub_download(repo_id='Jenthe/ECAPA2', filename='ecapa2.pt', cache_dir=None)
ecapa2 = torch.jit.load(ecapa2_file, map_location='cpu').to(device)

# %%
def torch_rms_norm(wav, db_level=-27.0):
    r = 10 ** (db_level / 20)
    a = torch.sqrt((wav.size(-1) * (r ** 2)) / torch.sum(wav ** 2))
    return wav * a

# %%
def get_ecapa2_spk_embedding(path=None, audio=None, ref_dBFS=None, model_sr=16000):
    if path is not None and path.exists():
        audio, sr = torchaudio.load(path)
        if audio.size(1) == 0:
            return None
    elif audio is not None:
        audio, sr = audio
        audio = torch.FloatTensor(audio).unsqueeze(0)
    else:
        raise ValueError('One of `path` or `audio` arguments should not be None')

    # sample rate of 16 kHz expected
    if sr != model_sr:
        audio = torchaudio.functional.resample(audio, sr, model_sr)

    # RMS norm based on the reference audio dBFS it make all models output in the same db level and it avoid issues
    if ref_dBFS is not None:
        audio = torch_rms_norm(audio, db_level=ref_dBFS)

    # compute speaker embedding
    embed = ecapa2(audio.to(device))
    # ensures that l2 norm is applied on output
    embed = torch.nn.functional.normalize(embed, p=2, dim=1)
    return embed.cpu().detach().squeeze().numpy()

# %%
vp_speakers = pd.read_csv('../data/facebook_voxpopuli/test_metadata.csv')
lg_speakers = pd.read_csv('../data/keithito_lj_speech/test_metadata.csv')

# %%
speaker_4525 = vp_speakers[vp_speakers['speaker_id'].isin([4525])]
speaker_197469= vp_speakers[vp_speakers['speaker_id'].isin([197469])]
speaker_lg = lg_speakers.sample(10, random_state=42)

# %%
emb_4525 = []
for _, row in speaker_4525.iterrows():
    audio_path = Path(f'../data/facebook_voxpopuli/wavs/{row["audio_id"]}.wav')
    ref_dBFS = AudioSegment.from_file(audio_path).dBFS
    emb_4525.append(get_ecapa2_spk_embedding(path=audio_path, ref_dBFS=ref_dBFS))

# %%
emb_197469 = []
for _, row in speaker_197469.iterrows():
    audio_path = Path(f'../data/facebook_voxpopuli/wavs/{row["audio_id"]}.wav')
    ref_dBFS = AudioSegment.from_file(audio_path).dBFS
    emb_197469.append(get_ecapa2_spk_embedding(path=audio_path, ref_dBFS=ref_dBFS))

# %%
emb_lg = []
for _, row in speaker_lg.iterrows():
    audio_path = Path(f'../data/keithito_lj_speech/wavs/{row["audio_id"]}.wav')
    ref_dBFS = AudioSegment.from_file(audio_path).dBFS
    emb_lg.append(get_ecapa2_spk_embedding(path=audio_path, ref_dBFS=ref_dBFS))

# %%
emb_4525 = np.vstack(emb_4525)

# %%
emb_197469=np.vstack(emb_197469)

# %%
emb_lg=np.vstack(emb_lg)

# %%
from sklearn.metrics.pairwise import cosine_distances

# %%
cosine_distances(emb_4525, emb_197469).mean()
# Out:
# 0.9190702

# %%
cosine_distances(emb_lg, emb_197469).mean()
# Out:
# 1.0102003

# %%
cosine_distances(emb_lg, emb_4525).mean()
# Out:
# 1.0549443

# %%
cosine_distances(emb_lg, emb_lg).mean()
# Out:
# 0.15678295

# %%
cosine_distances(emb_4525, emb_4525).mean()
# Out:
# 0.23634158

# %%
cosine_distances(emb_4525, emb_4525).mean()

# %%
metadata = pd.read_csv('../data/keithito_lj_speech/metadata.csv')
metadata
# Out:
#          audio_id                                           raw_text  \
# 0      LJ049-0081  There was no Federal criminal jurisdiction ove...
# 1      LJ028-0384               So Babylon was buried and forgotten.
# 2      LJ034-0111  When arrested, he gave his weight as 140 pound...
# 3      LJ030-0101  Admiral George G. Burkley, physician to the Pr...
# 4      LJ034-0171  Edwards said, quote, Look at that guy there in...
# ...           ...                                                ...
# 13094  LJ013-0152  at Montreuil. He was arraigned at the Old Bail...
# 13095  LJ045-0052  which Mrs. Paine had made in part to give her ...
# 13096  LJ019-0382  As the years passed, great want of uniformity ...
# 13097  LJ007-0186  the undue authority given to prisoners, the le...
# 13098  LJ036-0082  Craig testified that later in the afternoon he...
#
#        speaker_id                              whisper_transcription
# 0      lg_speaker   There was no federal criminal jurisdiction ov...
# 1      lg_speaker               So Babylon was buried and forgotten.
# 2      lg_speaker   When arrested he gave his weight as 140 pound...
# 3      lg_speaker   Admiral George G. Berkeley, physician to the ...
# 4      lg_speaker   Edwards said, quote, look at that guy there i...
# ...           ...                                                ...
# 13094  lg_speaker   at Montreuil. He was arraigned at the Old Bai...
# 13095  lg_speaker   which Mrs. Payne had made, in part, to give h...
# 13096  lg_speaker   As the years passed, great want of uniformity...
# 13097  lg_speaker   the undue authority given to prisoners, the l...
# 13098  lg_speaker   Craig testified that later in the afternoon h...
#
# [13099 rows x 4 columns]

# %%
metadata.sort_values('audio_id')
# Out:
#          audio_id                                           raw_text  \
# 4693   LJ001-0002                     in being comparatively modern.
# 3108   LJ001-0003  For although the Chinese took impressions from...
# 5778   LJ001-0004  produced the block books, which were the immed...
# 3187   LJ001-0005  the invention of movable metal letters in the ...
# 662    LJ001-0006  And it is worth mention in passing that, as an...
# ...           ...                                                ...
# 2350   LJ050-0274  made certain recommendations which it believes...
# 10228  LJ050-0275  materially improve upon the procedures in effe...
# 1171   LJ050-0276  As has been pointed out, the Commission has no...
# 5405   LJ050-0277  with the active cooperation of the responsible...
# 6768   LJ050-0278  the recommendations we have here suggested wou...
#
#        speaker_id                              whisper_transcription
# 4693   lg_speaker                     in being comparatively modern.
# 3108   lg_speaker   For although the Chinese took impressions fro...
# 5778   lg_speaker   produced the block books, which were the imme...
# 3187   lg_speaker   The invention of movable metal letters in the...
# 662    lg_speaker   And it is worth mention in passing that as an...
# ...           ...                                                ...
# 2350   lg_speaker   made certain recommendations, which it believ...
# 10228  lg_speaker   materially improve upon the procedures in eff...
# 1171   lg_speaker   As has been pointed out, the Commission has n...
# 5405   lg_speaker   with the active cooperation of the responsibl...
# 6768   lg_speaker   The recommendations we have here suggested wo...
#
# [13099 rows x 4 columns]

# %%
metadata['raw_text'].unique().shape
# Out:
# (13073,)

# %%
lg_prompts = metadata.sort_values('audio_id').iloc[1:]['raw_text'].unique()
lg_prompts = pd.Series(lg_prompts, name='prompt')
lg_prompts
# Out:
# 0        For although the Chinese took impressions from...
# 1        produced the block books, which were the immed...
# 2        the invention of movable metal letters in the ...
# 3        And it is worth mention in passing that, as an...
# 4        "the earliest book printed with movable types,...
#                                ...
# 13067    made certain recommendations which it believes...
# 13068    materially improve upon the procedures in effe...
# 13069    As has been pointed out, the Commission has no...
# 13070    with the active cooperation of the responsible...
# 13071    the recommendations we have here suggested wou...
# Name: prompt, Length: 13072, dtype: object

# %%
lg_prompts.to_frame().to_csv('../data/dpo_dataset/lg_prompts.csv', index=False)

# %%
df = pd.read_parquet('../data/dpo_dataset/finale_samples.parquet')
df
# Out:
#    gen_id      audio_id speaker_id  prompt_id  \
# 0       0  p236_441.wav   p236_441       5600
# 1       1  p236_441.wav   p236_441       5600
# 2       2  p236_441.wav   p236_441       5600
# 3       3  p236_441.wav   p236_441       5600
# 4       4  p236_441.wav   p236_441       5600
# ..    ...           ...        ...        ...
# 95      5  p239_429.wav   p239_429       1016
# 96      6  p239_429.wav   p239_429       1016
# 97      7  p239_429.wav   p239_429       1016
# 98      8  p239_429.wav   p239_429       1016
# 99      9  p239_429.wav   p239_429       1016
#
#                                                  text  \
# 0   Through rigorous market analysis, the investme...
# 1   Through rigorous market analysis, the investme...
# 2   Through rigorous market analysis, the investme...
# 3   Through rigorous market analysis, the investme...
# 4   Through rigorous market analysis, the investme...
# ..                                                ...
# 95  While negotiating with the opposing party, the...
# 96  While negotiating with the opposing party, the...
# 97  While negotiating with the opposing party, the...
# 98  While negotiating with the opposing party, the...
# 99  While negotiating with the opposing party, the...
#
#                                             gpt_codes       cer       mer  \
# 0   [8, 28, 256, 728, 105, 371, 325, 577, 487, 225...  0.000000  0.000000
# 1   [8, 28, 256, 604, 487, 82, 838, 467, 225, 587,...  0.000000  0.000000
# 2   [294, 256, 325, 445, 728, 487, 467, 459, 225, ...  0.181818  0.166667
# 3   [746, 256, 333, 728, 487, 82, 577, 225, 28, 12...  0.000000  0.000000
# 4   [305, 82, 256, 270, 105, 487, 467, 536, 225, 2...  0.000000  0.000000
# ..                                                ...       ...       ...
# 95  [483, 288, 49, 775, 257, 584, 161, 128, 119, 2...  0.000000  0.000000
# 96  [483, 288, 775, 257, 299, 304, 433, 584, 871, ...  0.000000  0.000000
# 97  [555, 288, 49, 435, 368, 299, 906, 128, 584, 1...  0.000000  0.000000
# 98  [30, 288, 299, 56, 269, 371, 193, 64, 59, 256,...  0.000000  0.000000
# 99  [466, 288, 299, 307, 352, 40, 360, 299, 256, 4...  0.000000  0.000000
#
#          wer       wil       wip      secs     utmos  cer_rank  secs_rank  \
# 0   0.000000  0.000000  1.000000  0.318090  4.197962         1          3
# 1   0.000000  0.000000  1.000000  0.247824  3.638512         2          1
# 2   0.181818  0.242424  0.757576  0.317722  3.883627        10          2
# 3   0.000000  0.000000  1.000000  0.356188  4.129373         3         10
# 4   0.000000  0.000000  1.000000  0.337849  4.014897         4          8
# ..       ...       ...       ...       ...       ...       ...        ...
# 95  0.000000  0.000000  1.000000  0.629990  4.193303         6          2
# 96  0.000000  0.000000  1.000000  0.627538  3.659092         7          1
# 97  0.000000  0.000000  1.000000  0.657178  3.848847         8          9
# 98  0.000000  0.000000  1.000000  0.650794  3.839072         9          5
# 99  0.000000  0.000000  1.000000  0.667993  4.194864        10         10
#
#     utmos_rank
# 0            9
# 1            1
# 2            4
# 3            8
# 4            7
# ..         ...
# 95           8
# 96           1
# 97           5
# 98           4
# 99           9
#
# [150000 rows x 16 columns]

# %%
def f3(row):
    cer = row['cer_rank'] /10
    secs = row['secs_rank']/10
    utmos = row['utmos_rank'] / 10

    return 3 / (1/cer+1/secs+1/utmos)

# %%
df['secs_rank'] = 11 - df['secs_rank']
df['utmos_rank'] = 11 - df['utmos_rank']
df['rank'] = df[['cer_rank', 'secs_rank', 'utmos_rank']].mean(axis=1)

# %%
df['f3_rank'] = df.apply(f3, axis=1)

# %%
def build_dataset(group):
    sorted_g = group.sort_values('f3_rank')
    good = sorted_g.iloc[1]
    bad = sorted_g.iloc[-2]
    res = pd.Series(
        {
            'audio_id': bad['audio_id'],
            'speaker_id': bad['speaker_id'],
            'text': bad['text'],
            'mel_cond_l': bad['gpt_codes'],
            'mel_cond_w': good['gpt_codes'],
            'l_rank':  bad['rank'],
            'w_rank': good['rank'],
        }
    )
    return res

# %%
df.groupby('prompt_id').apply(build_dataset).to_parquet('../data/dpo_dataset/finale_dpo_data.parquet')

# %%
df[df['prompt_id'] == 100].sort_values('f3_rank')
# Out:
#    gen_id                                           audio_id  \
# 89      9  20150610-0900-PLENARY-15-en_20150610-19_26_22_...
# 80      0  20150610-0900-PLENARY-15-en_20150610-19_26_22_...
# 83      3  20150610-0900-PLENARY-15-en_20150610-19_26_22_...
# 81      1  20150610-0900-PLENARY-15-en_20150610-19_26_22_...
# 86      6  20150610-0900-PLENARY-15-en_20150610-19_26_22_...
# 84      4  20150610-0900-PLENARY-15-en_20150610-19_26_22_...
# 88      8  20150610-0900-PLENARY-15-en_20150610-19_26_22_...
# 87      7  20150610-0900-PLENARY-15-en_20150610-19_26_22_...
# 85      5  20150610-0900-PLENARY-15-en_20150610-19_26_22_...
# 82      2  20150610-0900-PLENARY-15-en_20150610-19_26_22_...
#
#                                          speaker_id  prompt_id  \
# 89  20150610-0900-PLENARY-15-en_20150610-19_26_22_9        100
# 80  20150610-0900-PLENARY-15-en_20150610-19_26_22_9        100
# 83  20150610-0900-PLENARY-15-en_20150610-19_26_22_9        100
# 81  20150610-0900-PLENARY-15-en_20150610-19_26_22_9        100
# 86  20150610-0900-PLENARY-15-en_20150610-19_26_22_9        100
# 84  20150610-0900-PLENARY-15-en_20150610-19_26_22_9        100
# 88  20150610-0900-PLENARY-15-en_20150610-19_26_22_9        100
# 87  20150610-0900-PLENARY-15-en_20150610-19_26_22_9        100
# 85  20150610-0900-PLENARY-15-en_20150610-19_26_22_9        100
# 82  20150610-0900-PLENARY-15-en_20150610-19_26_22_9        100
#
#                                                  text  \
# 89  Key performance indicators showed a substantia...
# 80  Key performance indicators showed a substantia...
# 83  Key performance indicators showed a substantia...
# 81  Key performance indicators showed a substantia...
# 86  Key performance indicators showed a substantia...
# 84  Key performance indicators showed a substantia...
# 88  Key performance indicators showed a substantia...
# 87  Key performance indicators showed a substantia...
# 85  Key performance indicators showed a substantia...
# 82  Key performance indicators showed a substantia...
#
#                                             gpt_codes  cer       mer  wer  \
# 89  [154, 392, 28, 82, 200, 640, 225, 338, 279, 62...  0.0  0.000000  0.0
# 80  [631, 225, 28, 82, 128, 640, 484, 76, 105, 365...  0.0  0.000000  0.0
# 83  [807, 28, 82, 640, 76, 225, 338, 154, 534, 487...  0.0  0.000000  0.0
# 81  [225, 28, 256, 487, 200, 534, 76, 627, 640, 44...  0.3  0.300000  0.3
# 86  [154, 99, 28, 82, 487, 85, 640, 225, 627, 13, ...  0.0  0.000000  0.0
# 84  [401, 28, 128, 627, 640, 76, 487, 338, 225, 36...  0.0  0.000000  0.0
# 88  [640, 225, 82, 368, 11, 730, 701, 551, 571, 91...  0.0  0.000000  0.0
# 87  [807, 99, 28, 82, 627, 76, 151, 487, 225, 640,...  0.0  0.000000  0.0
# 85  [85, 28, 82, 640, 571, 225, 487, 76, 831, 551,...  0.0  0.000000  0.0
# 82  [571, 225, 28, 1003, 82, 99, 640, 487, 76, 13,...  0.2  0.181818  0.2
#
#          wil       wip      secs     utmos  cer_rank  secs_rank  utmos_rank  \
# 89  0.000000  1.000000  0.130334  3.601701         8          1           1
# 80  0.000000  1.000000  0.083068  2.871134         1          7           6
# 83  0.000000  1.000000  0.099155  3.437140         2          4           2
# 81  0.510000  0.490000  0.123393  1.745540        10          2          10
# 86  0.000000  1.000000  0.084750  3.412921         5          6           3
# 84  0.000000  1.000000  0.054122  3.043425         3          9           5
# 88  0.000000  1.000000  0.115861  2.285100         7          3           9
# 87  0.000000  1.000000  0.072053  3.133993         6          8           4
# 85  0.000000  1.000000  0.045662  2.521324         4         10           7
# 82  0.263636  0.736364  0.097615  2.461971         9          5           8
#
#         rank   f3_rank
# 89  3.333333  0.141176
# 80  4.666667  0.229091
# 83  2.666667  0.240000
# 81  7.333333  0.428571
# 86  4.666667  0.428571
# 84  5.666667  0.465517
# 88  6.333333  0.510811
# 87  6.000000  0.553846
# 85  7.000000  0.608696
# 82  7.333333  0.687898

# %%
df[df['prompt_id'] == 101].sort_values('f3_rank')
# Out:
#    gen_id        audio_id  speaker_id  prompt_id  \
# 50      0  LJ001-0001.wav  LJ001-0001        101
# 55      5  LJ001-0001.wav  LJ001-0001        101
# 59      9  LJ001-0001.wav  LJ001-0001        101
# 56      6  LJ001-0001.wav  LJ001-0001        101
# 51      1  LJ001-0001.wav  LJ001-0001        101
# 54      4  LJ001-0001.wav  LJ001-0001        101
# 53      3  LJ001-0001.wav  LJ001-0001        101
# 52      2  LJ001-0001.wav  LJ001-0001        101
# 57      7  LJ001-0001.wav  LJ001-0001        101
# 58      8  LJ001-0001.wav  LJ001-0001        101
#
#                                                  text  \
# 50  The novelist's brushstrokes danced with vibran...
# 55  The novelist's brushstrokes danced with vibran...
# 59  The novelist's brushstrokes danced with vibran...
# 56  The novelist's brushstrokes danced with vibran...
# 51  The novelist's brushstrokes danced with vibran...
# 54  The novelist's brushstrokes danced with vibran...
# 53  The novelist's brushstrokes danced with vibran...
# 52  The novelist's brushstrokes danced with vibran...
# 57  The novelist's brushstrokes danced with vibran...
# 58  The novelist's brushstrokes danced with vibran...
#
#                                             gpt_codes  cer  mer  wer  \
# 50  [701, 25, 270, 256, 487, 258, 627, 151, 28, 22...  0.0  0.0  0.0
# 55  [534, 299, 368, 211, 371, 12, 225, 627, 487, 1...  0.0  0.0  0.0
# 59  [534, 642, 115, 256, 487, 258, 627, 225, 128, ...  0.1  0.1  0.1
# 56  [200, 323, 11, 266, 173, 7, 226, 338, 65, 66, ...  0.0  0.0  0.0
# 51  [534, 25, 527, 767, 68, 323, 226, 200, 266, 66...  0.0  0.0  0.0
# 54  [17, 256, 269, 368, 299, 56, 74, 627, 487, 301...  0.3  0.3  0.3
# 53  [627, 767, 527, 160, 59, 481, 775, 30, 487, 35...  0.1  0.1  0.1
# 52  [551, 405, 369, 299, 59, 435, 561, 323, 266, 6...  0.2  0.2  0.2
# 57  [627, 871, 527, 68, 323, 59, 727, 405, 256, 48...  0.1  0.1  0.1
# 58  [534, 487, 167, 82, 225, 258, 627, 587, 151, 2...  0.1  0.1  0.1
#
#          wil       wip      secs     utmos  cer_rank  secs_rank  utmos_rank  \
# 50  0.000000  1.000000  0.380009  3.960942         1          3           3
# 55  0.000000  1.000000  0.327664  4.182682         3          8           1
# 59  0.190000  0.810000  0.402301  3.674850         8          1           5
# 56  0.000000  1.000000  0.337886  4.109210         4          6           2
# 51  0.000000  1.000000  0.295025  3.718721         2         10           4
# 54  0.455556  0.544444  0.399505  3.647018        10          2           6
# 53  0.190000  0.810000  0.371423  3.643049         5          4           7
# 52  0.288889  0.711111  0.341844  3.468195         9          5          10
# 57  0.100000  0.900000  0.300127  3.623864         6          9           8
# 58  0.190000  0.810000  0.330368  3.603032         7          7           9
#
#         rank   f3_rank
# 50  2.333333  0.180000
# 55  4.000000  0.205714
# 59  4.666667  0.226415
# 56  4.000000  0.327273
# 51  5.333333  0.352941
# 54  6.000000  0.391304
# 53  5.333333  0.506024
# 52  8.000000  0.729730
# 57  7.666667  0.744828
# 58  7.666667  0.756000

# %%
def f(group):
    sort_group = group.sort_values('rank').iloc[0]
    return sum(sort_group[['cer_rank', 'secs_rank', 'utmos_rank']] > 5)

# %%
df.groupby('prompt_id').apply(f).mean()
# Out:
# 0.3156

# %%
_.mean()
# Out:
# 0.0

# %%
df['cer'].max()
# Out:
# 39.09090909090909
