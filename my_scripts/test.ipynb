# %%
import random

import numpy as np
import matplotlib.pyplot as plt
from rich.jupyter import display

# %%
np.random.rand((10))

# %%
plt.plot(np.random.rand(10))

# %%
import pandas as pd

# %%
import ollama
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File F:\miniconda3\envs\diploma_env\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File F:\miniconda3\envs\diploma_env\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File F:\miniconda3\envs\diploma_env\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
# ...

# %%
from tqdm import notebook

# %%
sentences = []
for i in notebook.tqdm(range(10)):
    resp = ollama.generate(
        'gemma2:9b-instruct-q4_0',
        'Generate sentence in styles of greate writers which have 10-15 word. Return only sentence without additional information.',
    )['response']
    sentences.append(resp)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 sentences = []
#       2 for i in notebook.tqdm(range(100)):
# ----> 3     resp = ollama.generate(
#       4         'gemma2:9b-instruct-q4_0',
#       5         'Generate sentence in styles of greate writers which have 10-15 word. Return only sentence without additional information.',
#       6     )['response']
#       7     sentences.append(resp)
#
# File F:\miniconda3\envs\diploma_env\Lib\site-packages\ollama\_client.py:163, in Client.generate(self, model, prompt, suffix, system, template, context, stream, raw, format, images, options, keep_alive)
#     160 if not model:
#     161   raise RequestError('must provide a model')
# --> 163 return self._request_stream(
#     164   'POST',
#     165   '/api/generate',
#     166   json={
# ...

# %%
sentences = []
for i in notebook.tqdm(range(10)):
    resp = ollama.generate(
        'gemma2:9b-instruct-q4_0',
        'Write story. Each sentence must have 10-15 word.',
    )['response']
    sentences.extend(resp.split('.'))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
prompt = '''Generate 20 unique sentences that meet these requirements:

1. Length constraints:
   - Each sentence should be between 5-15 words
   - Vary sentence lengths naturally within this range

2. Structural diversity:
   - Mix simple, compound, and complex sentences
   - Use different sentence openings (subject, prepositional phrase, gerund, etc.)
   - Vary between declarative, interrogative, and exclamatory sentences
   - Include both active and passive voice constructions

3. Vocabulary requirements:
   - Use precise, specific verbs instead of generic ones (e.g., "sprint" vs "run")
   - Include descriptive adjectives and adverbs without overuse
   - Avoid repeating words across sentences except for essential articles and prepositions
   - Draw vocabulary from different domains (nature, technology, daily life, etc.)

4. Semantic constraints:
   - Each sentence should be logically coherent and self-contained
   - Include both concrete and abstract concepts
   - Vary emotional tone (neutral, positive, negative)
   - Mix formal and informal register

5. Format output as:
   - One sentence per line
   - Number each sentence
   - Include a brief tag indicating primary structure type [Simple/Compound/Complex]

# Example Output Format:

1. [Simple] The old maple tree erupted in autumn colors.
2. [Complex] While thunder rolled across the valley, migrating geese soared southward.
3. [Compound] The quarterback fumbled the ball, but his teammate recovered it swiftly.

# Additional Parameters:
- Domain focus: Team Sports
- Tone emphasis: formal
'''

# %%
tones = ['formal', 'informal']
domains = '''
# Academic & Scientific Domains

1. Biology & Life Sciences
   - Example: "The mitochondria efficiently converted glucose into cellular energy."
   - Subtopics: genetics, ecology, anatomy, evolution

2. Physics & Astronomy
   - Example: "Neutron stars collapse under their intense gravitational force."
   - Subtopics: quantum mechanics, cosmology, thermodynamics

3. Chemistry
   - Example: "The catalyst accelerated the reaction without being consumed."
   - Subtopics: organic chemistry, materials science, biochemistry

# Professional & Technical Domains

4. Business & Finance
   - Example: "The merger created substantial synergies for both companies."
   - Subtopics: marketing, accounting, investments, management

5. Technology & Computing
   - Example: "The algorithm efficiently sorted through millions of data points."
   - Subtopics: programming, cybersecurity, artificial intelligence

6. Engineering
   - Example: "The bridge's suspension cables distributed weight evenly."
   - Subtopics: mechanical, electrical, civil, aerospace

# Everyday Life Domains

7. Daily Activities
   - Example: "She quickly prepared breakfast while checking her emails."
   - Subtopics: routines, chores, work life, leisure

8. Social Interactions
   - Example: "The neighbors gathered for their annual block party."
   - Subtopics: relationships, communication, events

9. Home & Living
   - Example: "Sunlight streamed through the newly installed skylight."
   - Subtopics: decoration, maintenance, gardening

# Arts & Culture Domains

10. Literature & Writing
    - Example: "The author crafted intricate metaphors throughout the novel."
    - Subtopics: poetry, journalism, creative writing

11. Visual Arts
    - Example: "The sculptor chiseled delicate features into the marble."
    - Subtopics: painting, photography, design

12. Performing Arts
    - Example: "The dancer executed a perfect pirouette on stage."
    - Subtopics: music, theater, dance

# Nature & Environment

13. Weather & Climate
    - Example: "Storm clouds gathered ominously on the horizon."
    - Subtopics: meteorology, seasons, natural phenomena

14. Geography & Landscapes
    - Example: "The canyon walls revealed millennia of geological history."
    - Subtopics: landforms, ecosystems, urban geography

15. Wildlife & Animals
    - Example: "The arctic fox's coat changed color with the seasons."
    - Subtopics: behavior, habitats, adaptation

# Sports & Recreation

16. Team Sports
    - Example: "The quarterback threw a perfect spiral to the receiver."
    - Subtopics: strategy, competition, training

17. Individual Sports
    - Example: "The gymnast maintained perfect balance on the beam."
    - Subtopics: techniques, equipment, performance

# Historical & Cultural

18. Historical Events
    - Example: "Ancient civilizations developed sophisticated irrigation systems."
    - Subtopics: wars, discoveries, social movements

19. Cultural Practices
    - Example: "Traditional artisans passed down their techniques through generations."
    - Subtopics: customs, traditions, celebrations

# Emotional & Psychological

20. Emotions & Feelings
    - Example: "Anticipation built as she opened the mysterious package."
    - Subtopics: moods, reactions, relationships
'''
_domains = []
for line in domains.split('\n'):
    if line.strip() and not (line.startswith(' ') or line.startswith('#')):
        _domains.append(line.split('.')[1].strip())

_domains
# Out:
# Generated 1500 valid combinations
#
# Prompt 1:
# Generate 11 unique sentences that meet these requirements:
#
# 1. Length constraints:
#    - Sentence length: 6-15 words
#    - Maximum word repetition: 2 times
#    - Technical term density: medium
#
# 2. Structural diversity:
#    - Mix simple, compound, and complex sentences
#    - Use different sentence openings (subject, prepositional phrase, gerund, etc.)
#    - Vary between declarative, interrogative, and exclamatory sentences
#    - Include both active and passive voice constructions
#
# 3. Vocabulary requirements:
#    - Use precise, specific verbs instead of generic ones (e.g., "sprint" vs "run")
#    - Include descriptive adjectives and adverbs without overuse
#    - Avoid repeating words across sentences except for essential articles and prepositions
#    - Draw vocabulary from different domains (nature, technology, daily life, etc.)
#
# 4. Semantic constraints:
# ...

# %%
from itertools import product
from typing import Dict, List, Tuple
import random
import json

class PromptCombinator:
    def __init__(self):
        # Define the parameter options
        self.parameters = {
            "domains": {
                "academic": ["biology", "physics", "chemistry"],
                "technical": ["computer_science", "engineering", "mathematics"],
                "natural": ["ecology", "weather", "geography"],
                "professional": ["business", "finance", "law"],
                "arts": ["literature", "visual_arts", "music"]
            },

            "vocabulary_requirements": {
                "parts_of_speech": {
                    "dynamic_verbs": [2, 3, 4],
                    "sensory_adjectives": [1, 2, 3],
                    "abstract_nouns": [1, 2],
                    "concrete_nouns": [2, 3, 4]
                },
                "register": ["formal", "informal", "mixed"],
                "specificity": ["technical", "general", "mixed"]
            },

            "structural_patterns": {
                "sentence_types": {
                    "simple": [20, 30, 40],  # percentage
                    "compound": [30, 40, 50],
                    "complex": [20, 30, 40]
                },
                "openers": ["adverbial", "participial", "prepositional", "subject"],
                "special_structures": ["periodic", "cumulative", "balanced", "parallel"]
            },

            "constraints": {
                "sentence_length": {
                    "min": [5, 6, 7],
                    "max": [12, 15, 18]
                },
                "word_repetition": [1, 2, 3],  # max times a word can be repeated
                "technical_density": ["low", "medium", "high"]  # percentage of technical terms
            }
        }

    def validate_sentence_distribution(self, simple: int, compound: int, complex: int) -> bool:
        """Check if sentence type percentages sum to 100"""
        return simple + compound + complex == 100

    def generate_combinations(self, max_combinations: int = 1000) -> List[Dict]:
        """Generate valid combinations of parameters"""
        # Create lists of items to combine
        domain_categories = list(self.parameters["domains"].keys())
        registers = self.parameters["vocabulary_requirements"]["register"]
        specificities = self.parameters["vocabulary_requirements"]["specificity"]
        openers = self.parameters["structural_patterns"]["openers"]
        special_structures = self.parameters["structural_patterns"]["special_structures"]
        technical_densities = self.parameters["constraints"]["technical_density"]

        # Generate combinations
        combinations = list(product(
            domain_categories,
            registers,
            specificities,
            openers,
            special_structures,
            technical_densities
        ))

        # Convert combinations to structured prompts
        prompts = []
        for combo in combinations:
            domain_cat, register, specificity, opener, special_structure, tech_density = combo

            # Only include valid sentence type distributions
            for simple in self.parameters["structural_patterns"]["sentence_types"]["simple"]:
                for compound in self.parameters["structural_patterns"]["sentence_types"]["compound"]:
                    for complex in self.parameters["structural_patterns"]["sentence_types"]["complex"]:
                        if self.validate_sentence_distribution(simple, compound, complex):
                            prompt = {
                                "domain": {
                                    "category": domain_cat,
                                    "specific_domains": self.parameters["domains"][domain_cat]
                                },
                                "vocabulary": {
                                    "register": register,
                                    "specificity": specificity,
                                    "requirements": {
                                        "dynamic_verbs": 3,  # Default values
                                        "sensory_adjectives": 2,
                                        "abstract_nouns": 1,
                                        "concrete_nouns": 2
                                    }
                                },
                                "structure": {
                                    "distribution": {
                                        "simple": simple,
                                        "compound": compound,
                                        "complex": complex
                                    },
                                    "preferred_opener": opener,
                                    "special_structure": special_structure
                                },
                                "constraints": {
                                    "sentence_length": {
                                        "min": 6,
                                        "max": 15
                                    },
                                    "word_repetition": 2,
                                    "technical_density": tech_density
                                }
                            }
                            prompts.append(prompt)

        return random.choices(prompts, k=max_combinations)

    def generate_prompt_text(self, params: Dict) -> str:
        """Convert parameter combination into actual prompt text"""
        prompt = f"""Generate 5 unique sentences that meet these requirements:

1. Length constraints:
   - Sentence length: {params['constraints']['sentence_length']['min']}-{params['constraints']['sentence_length']['max']} words
   - Maximum word repetition: {params['constraints']['word_repetition']} times
   - Technical term density: {params['constraints']['technical_density']}

2. Structural diversity:
   - Mix simple, compound, and complex sentences
   - Use different sentence openings (subject, prepositional phrase, gerund, etc.)
   - Vary between declarative, interrogative, and exclamatory sentences
   - Include both active and passive voice constructions

3. Vocabulary requirements:
   - Use precise, specific verbs instead of generic ones (e.g., "sprint" vs "run")
   - Include descriptive adjectives and adverbs without overuse
   - Avoid repeating words across sentences except for essential articles and prepositions
   - Draw vocabulary from different domains (nature, technology, daily life, etc.)

4. Semantic constraints:
   - Each sentence should be logically coherent and self-contained
   - Include both concrete and abstract concepts
   - Vary emotional tone (neutral, positive, negative)
   - Mix formal and informal register

5. Format output as:
   - One sentence per line
   - Number each sentence
   - Include a brief tag indicating primary structure type [Simple/Compound/Complex]
   - Return only sentences without additional information.

# Additional Parameters:
   Domain:
      - Category: {params['domain']['category']}
      - Focus areas: {', '.join(params['domain']['specific_domains'])}

   Vocabulary:
      - Register: {params['vocabulary']['register']}
      - Specificity: {params['vocabulary']['specificity']}
      - Required elements per sentence:
        * Dynamic verbs: {params['vocabulary']['requirements']['dynamic_verbs']}
        * Sensory adjectives: {params['vocabulary']['requirements']['sensory_adjectives']}
        * Abstract nouns: {params['vocabulary']['requirements']['abstract_nouns']}
        * Concrete nouns: {params['vocabulary']['requirements']['concrete_nouns']}

   Structure:
      - Sentence type distribution:
        * Simple: {params['structure']['distribution']['simple']}%
        * Compound: {params['structure']['distribution']['compound']}%
        * Complex: {params['structure']['distribution']['complex']}%
      - Preferred opener: {params['structure']['preferred_opener']}
      - Special structure: {params['structure']['special_structure']}

# Example Output Format:

1. [Simple] The old maple tree erupted in autumn colors.
2. [Complex] While thunder rolled across the valley, migrating geese soared southward.
3. [Compound] The quarterback fumbled the ball, but his teammate recovered it swiftly.
"""
        return prompt
# Out:
#   0%|          | 0/1500 [00:00<?, ?it/s]

# %%
combinator = PromptCombinator()

# Generate combinations
combinations = combinator.generate_combinations(max_combinations=100)

# Generate some example prompts
print(f"Generated {len(combinations)} valid combinations")

# Print a few example prompts
prompts = []
for i, combo in enumerate(combinations[:3]):
    print(f"\nPrompt {i+1}:")
    print(combinator.generate_prompt_text(combo))
    print("-" * 80)
    prompts.append(combinator.generate_prompt_text(combo))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
sentences_llama = []
for i, combo in notebook.tqdm(enumerate(combinations), total=len(combinations)):
    prompt = combinator.generate_prompt_text(combo)
    resp = ollama.generate(
        'llama3.2',
        prompt,
    )['response']
    sentences_llama.append(resp)

# %%
sentences_gemma = []
for i, combo in notebook.tqdm(enumerate(combinations), total=len(combinations)):
    prompt = combinator.generate_prompt_text(combo)
    resp = ollama.generate(
        'gemma2:2b',
        prompt,
    )['response']
    sentences_gemma.append(resp)

# %%
def split_sentence(sentence):
    sentence = sentence.split('\n\n')
    if len(sentence) > 1:
        return sentence[1]
    
    return sentence[0]


def format_sentences(sentences):
    sentences = [split_sentence(sentence) for sentence in sentences]
    sentences = [sentence.split('\n') for sentence in sentences]
    sentences = sum(sentences, [])
    sentences = pd.Series(sentences)
    sentences = sentences[sentences.apply(lambda x: '[' in x and ']' in x)]
    sentences = sentences.apply(lambda x: x.split(']')[1].strip())
    return sentences
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 sentences_llama_s = format_sentences(sentences_llama)
# ----> 2 sentences_gemma_s = format_sentences(sentences_gemma)
#
# NameError: name 'sentences_gemma' is not defined

# %%
sentences_llama
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 sentences_llama_s = format_sentences(sentences_llama)
# ----> 2 sentences_gemma_s = format_sentences(sentences_gemma)
#
# NameError: name 'sentences_gemma' is not defined

# %%
sentences_llama_s = format_sentences(sentences_llama)
sentences_gemma_s = format_sentences(sentences_gemma)
# Out:
# 0        After analyzing market trends, our financial t...
# 1        The CEO's presentation focused on innovative s...
# 2        As the sales figures revealed, the marketing s...
# 3        What a relief it felt when we finally closed t...
# 4        The company's commitment to corporate social r...
#                                ...
# 15496    The marketing strategy involved a multi-channe...
# 15497    As negotiations between the parties drew to a ...
# 15498    The company's new policy aimed to reduce carbo...
# 15499    Through a combination of rigorous testing and ...
# 15500    The innovative technology utilized advanced ma...
# Length: 15475, dtype: object

# %%
sentences_gemma
# Out:
# 0      The painter's bold brushstrokes danced across ...
# 1      As she wandered through the gallery, the poet'...
# 2      With each note, the musician's fingers weaved ...
# 3      The scent of fresh paint wafted from the open ...
# 4      Through the city streets, the sound system rev...
#                              ...
# 463    Flickering LED lights illuminated the dark roo...
# 464    As engineers designed a new algorithm, they di...
# 465    The researchers conducted extensive tests, obt...
# 466    With her quick reflexes, the firefighter avoid...
# 467    In a surprising twist, the company's CEO annou...
# Length: 464, dtype: object

# %%
sentences_llama_s
# Out:
# 0      As morning sunbeams pierced the forest canopy,...
# 1      The stormy weather brought heavy rainfall and ...
# 2      In contrast to yesterday's calmness, today's f...
# 3      Oh, what a breathtaking sight the aurora borea...
# 4      The vast expanse of the Grand Canyon revealed ...
#                              ...
# 471    As electrons oscillated around the nucleus, qu...
# 472    Oxygen levels in freshwater sources are crucia...
# 473    The researcher carefully analyzed data using s...
# 474    When photons collided with atomic nuclei, incr...
# 475    Through recursive processes of mitosis and mei...
# Length: 466, dtype: object

# %%
sentences_gemma_s

# %%
sentences_gemma_s.name = 'gemma2-2b-prompt'
sentences_llama_s.name = 'llama3.2-3b-prompt'

sentences_gemma_s.to_frame().to_csv('../data/dpo_texts_samples/gemma.csv')
sentences_llama_s.to_frame().to_csv('../data/dpo_texts_samples/llama.csv')
# Out:
# 15408

# %%
pd.concat([sentences_llama_s, sentences_gemma_s],axis=1)
# Out:
#                                     llama3.2-3b-prompt  \
# 0    As morning sunbeams pierced the forest canopy,...
# 1    The stormy weather brought heavy rainfall and ...
# 2    In contrast to yesterday's calmness, today's f...
# 3    Oh, what a breathtaking sight the aurora borea...
# 4    The vast expanse of the Grand Canyon revealed ...
# ..                                                 ...
# 511                                                NaN
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
# 515                                                NaN
#
#                                       gemma2-2b-prompt
# 0    Verdant leaves burst into vibrant hues as fall...
# 1    The wind whips through tall grasses as moistur...
# 2    The biologist's meticulously observed the migr...
# 3    A symphony of chirps echoed through the dense ...
# ...

# %%
sentences = [sentence.split('\n\n')[1] for sentence in sentences]

# %%
sentences = [sentence.split('\n') for sentence in sentences]
sentences = sum(sentences, [])

# %%
pd.Series(sentences)
# Out:
# 0       1. [Simple] The biologist carefully measured t...
# 1       2. [Complex] As the solar eclipse approached, ...
# 2       3. [Compound] With each step, the hikers climb...
# 3       4. [Exclamatory] What an incredible feat of en...
# 4       5. [Simple] The physicist hypothesized a new t...
#                               ...
# 1357    16. [Interrogative] Does the new material exhi...
# 1358    17. [Simple] The ocean's surface temperature f...
# 1359    18. [Complex] Through advanced statistical ana...
# 1360    19. [Compound] The biodegradable polymer showe...
# 1361    20. [Exclamatory] The groundbreaking discovery...
# Length: 1362, dtype: object

# %%
sentences = [sentence.split('\n') for sentence in sentences]
sentences = sum(sentences, [])

# %%
sentences = pd.Series(sentences)
sentences = sentences[sentences.apply(lambda x: '[' in x and ']' in x)]
sentences
# Out:
# 0       1. [Simple] The biologist carefully measured t...
# 1       2. [Complex] As the solar eclipse approached, ...
# 2       3. [Compound] With each step, the hikers climb...
# 3       4. [Exclamatory] What an incredible feat of en...
# 4       5. [Simple] The physicist hypothesized a new t...
#                               ...
# 1357    16. [Interrogative] Does the new material exhi...
# 1358    17. [Simple] The ocean's surface temperature f...
# 1359    18. [Complex] Through advanced statistical ana...
# 1360    19. [Compound] The biodegradable polymer showe...
# 1361    20. [Exclamatory] The groundbreaking discovery...
# Length: 1362, dtype: object

# %%
sentences = sentences.apply(lambda x: x.split(']')[1].strip())
sentences
# Out:
# 0       The biologist carefully measured the diameter ...
# 1       As the solar eclipse approached, physicists ca...
# 2       With each step, the hikers climbed higher into...
# 3       What an incredible feat of engineering that sk...
# 4       The physicist hypothesized a new theory to exp...
#                               ...
# 1357    Does the new material exhibit improved thermal...
# 1358    The ocean's surface temperature fluctuated wit...
# 1359    Through advanced statistical analysis, researc...
# 1360    The biodegradable polymer showed remarkable re...
# 1361    The groundbreaking discovery revolutionized ou...
# Length: 1362, dtype: object

# %%
import pandas as pd

# %%
metadata = pd.read_parquet('../data/dpo_dataset/samples_data.parquet')
metadata
# Out:
#     gen_id                                  audio_id     speaker_id  \
# 0        0  dd116c13-a4ca-11ef-a829-346f24a52a12.wav  constance-035
# 1        1  de61bef4-a4ca-11ef-adc2-346f24a52a12.wav  constance-035
# 2        2  dfaeebc0-a4ca-11ef-9a51-346f24a52a12.wav  constance-035
# 3        3  e1077360-a4ca-11ef-95da-346f24a52a12.wav  constance-035
# 4        4  e2706d5a-a4ca-11ef-aa75-346f24a52a12.wav  constance-035
# ..     ...                                       ...            ...
# 245      0  46e9dcc7-a4cc-11ef-a2f1-346f24a52a12.wav    vincent-001
# 246      1  492fe4f0-a4cc-11ef-9894-346f24a52a12.wav    vincent-001
# 247      2  4aa98f55-a4cc-11ef-ba33-346f24a52a12.wav    vincent-001
# 248      3  4c1533f8-a4cc-11ef-a26e-346f24a52a12.wav    vincent-001
# 249      4  4d8e669d-a4cc-11ef-baf7-346f24a52a12.wav    vincent-001
#
#                                                   text  \
# 0    As morning sunbeams pierced the forest canopy,...
# ...

# %%
samples = metadata.groupby(['speaker_id', 'text']).sample(2, random_state=42)
samples
# Out:
#     gen_id                                  audio_id   speaker_id  \
# 6        1  e4f364e1-a4ca-11ef-b0f6-346f24a52a12.wav   LJ001-0001
# 9        4  e8cd4603-a4ca-11ef-a789-346f24a52a12.wav   LJ001-0001
# 133      3  92b49ff6-a4cb-11ef-83b7-346f24a52a12.wav   LJ001-0001
# 131      1  901cf6a8-a4cb-11ef-9b0f-346f24a52a12.wav   LJ001-0001
# 56       1  227f7427-a4cb-11ef-b78f-346f24a52a12.wav   LJ001-0001
# ..     ...                                       ...          ...
# 47       2  16d27dd1-a4cb-11ef-ba05-346f24a52a12.wav  vincent-001
# 121      1  8213df7f-a4cb-11ef-95e9-346f24a52a12.wav  vincent-001
# 122      2  833abc91-a4cb-11ef-bf84-346f24a52a12.wav  vincent-001
# 195      0  e0daf1d0-a4cb-11ef-9199-346f24a52a12.wav  vincent-001
# 198      3  e5a3b571-a4cb-11ef-9da1-346f24a52a12.wav  vincent-001
#
#                                                   text  \
# 6    As morning sunbeams pierced the forest canopy,...
# 9    As morning sunbeams pierced the forest canopy,...
# ...

# %%
mel_cond_w = samples.groupby(['speaker_id', 'text']).nth(0)
mel_cond_w
# Out:
#                                                                  gen_id  \
# speaker_id    text
# LJ001-0001    As morning sunbeams pierced the forest canopy, ...      1
#               As negotiations concluded, key stakeholders cap...      3
#               In contrast to yesterday's calmness, today's fo...      1
#               Innovative software applications have transform...      0
#               Meanwhile, across town, experts debated the imp...      0
#               Oh, what a breathtaking sight the aurora boreal...      4
#               The finance minister disclosed the budget cuts ...      2
#               The stormy weather brought heavy rainfall and s...      1
#               The vast expanse of the Grand Canyon revealed h...      0
#               Under close supervision from investors and audi...      0
# constance-035 As morning sunbeams pierced the forest canopy, ...      0
#               As negotiations concluded, key stakeholders cap...      1
# ...

# %%
mel_cond_l = samples.groupby(['speaker_id', 'text']).nth(1)
mel_cond_l
# Out:
#                                                                  gen_id  \
# speaker_id    text
# LJ001-0001    As morning sunbeams pierced the forest canopy, ...      4
#               As negotiations concluded, key stakeholders cap...      1
#               In contrast to yesterday's calmness, today's fo...      0
#               Innovative software applications have transform...      1
#               Meanwhile, across town, experts debated the imp...      2
#               Oh, what a breathtaking sight the aurora boreal...      2
#               The finance minister disclosed the budget cuts ...      0
#               The stormy weather brought heavy rainfall and s...      2
#               The vast expanse of the Grand Canyon revealed h...      3
#               Under close supervision from investors and audi...      1
# constance-035 As morning sunbeams pierced the forest canopy, ...      1
#               As negotiations concluded, key stakeholders cap...      3
# ...

# %%
(mel_cond_w['gen_id'] == mel_cond_l['gen_id']).sum()
# Out:
# 0

# %%
df = mel_cond_w.copy()
df.rename(columns={'gpt_codes': 'mel_cond_w'}, inplace=True)
df.drop(columns=['gen_id'], inplace=True)

df['mel_cond_l'] = mel_cond_l['gpt_codes']
df
# Out:
#                                                                                                   audio_id  \
# speaker_id    text
# LJ001-0001    As morning sunbeams pierced the forest canopy, ...  e4f364e1-a4ca-11ef-b0f6-346f24a52a12.wav
#               As negotiations concluded, key stakeholders cap...  92b49ff6-a4cb-11ef-83b7-346f24a52a12.wav
#               In contrast to yesterday's calmness, today's fo...  227f7427-a4cb-11ef-b78f-346f24a52a12.wav
#               Innovative software applications have transform...  efec9fcb-a4cb-11ef-8fb1-346f24a52a12.wav
#               Meanwhile, across town, experts debated the imp...  267c2f6c-a4cc-11ef-8bb1-346f24a52a12.wav
#               Oh, what a breathtaking sight the aurora boreal...  48dfbed8-a4cb-11ef-9ca7-346f24a52a12.wav
#               The finance minister disclosed the budget cuts ...  b06cade4-a4cb-11ef-9df3-346f24a52a12.wav
# ...

# %%
df.reset_index().to_parquet('../data/dpo_dataset/metadata.parquet')

# %%
df= pd.read_parquet('../data/dpo_dataset/metadata.parquet')
df
# Out:
#        speaker_id                                               text  \
# 0      LJ001-0001  As morning sunbeams pierced the forest canopy,...
# 1      LJ001-0001  As negotiations concluded, key stakeholders ca...
# 2      LJ001-0001  In contrast to yesterday's calmness, today's f...
# 3      LJ001-0001  Innovative software applications have transfor...
# 4      LJ001-0001  Meanwhile, across town, experts debated the im...
# 5      LJ001-0001  Oh, what a breathtaking sight the aurora borea...
# 6      LJ001-0001  The finance minister disclosed the budget cuts...
# 7      LJ001-0001  The stormy weather brought heavy rainfall and ...
# 8      LJ001-0001  The vast expanse of the Grand Canyon revealed ...
# 9      LJ001-0001  Under close supervision from investors and aud...
# 10  constance-035  As morning sunbeams pierced the forest canopy,...
# 11  constance-035  As negotiations concluded, key stakeholders ca...
# 12  constance-035  In contrast to yesterday's calmness, today's f...
# ...

# %% [markdown]
# # Choosing CMOS speakers
# ## VCTK

# %%
# %matplotlib inline
import pandas as pd
import random as rd
from IPython.display import Audio

rd.seed(42)

# %%
vctk_df = pd.read_csv('../data/VCTK-Corpus/test_metadata.csv')
vctk_df
# Out:
#      speaker_id      audio_id  \
# 0          p225  p225_016.wav
# 1          p225  p225_022.wav
# 2          p225  p225_060.wav
# 3          p225  p225_062.wav
# 4          p225  p225_066.wav
# ...         ...           ...
# 4402       p376  p376_259.wav
# 4403       p376  p376_263.wav
# 4404       p376  p376_272.wav
# 4405       p376  p376_284.wav
# 4406       p376  p376_285.wav
#
#                                                    text  \
# 0     The Norsemen considered the rainbow as a bridg...
# 1     The actual primary rainbow observed is said to...
# 2       Strathclyde police have appealed for witnesses.
# 3           I was very pleased with them today, though.
# 4                          It is a job creation scheme.
# ...                                                 ...
# 4402  It is not satisfied with the standard of fire ...
# 4403  Similar measures are expected in England and W...
# 4404                                      Its so awful.
# ...

# %%
vcsk_speakers = pd.read_csv('../data/VCTK-Corpus/speaker_info.csv')
vcsk_speakers
# Out:
#       ID  AGE GENDER     ACCENTS            REGION
# 0    225   23      F     English  Southern England
# 1    226   22      M     English            Surrey
# 2    227   38      M     English           Cumbria
# 3    228   22      F     English  Southern England
# 4    229   23      F     English  Southern England
# ..   ...  ...    ...         ...               ...
# 103  362   29      F    American               NaN
# 104  363   22      M    Canadian           Toronto
# 105  364   23      M       Irish           Donegal
# 106  374   28      M  Australian           English
# 107  376   22      M      Indian               NaN
#
# [108 rows x 5 columns]

# %%
vcsk_speakers = vcsk_speakers[vcsk_speakers['ID'].isin(vctk_df['speaker_id'].str.removeprefix('p').apply(int).unique())]
vcsk_speakers
# Out:
#       ID  AGE GENDER     ACCENTS            REGION
# 0    225   23      F     English  Southern England
# 1    226   22      M     English            Surrey
# 2    227   38      M     English           Cumbria
# 3    228   22      F     English  Southern England
# 4    229   23      F     English  Southern England
# ..   ...  ...    ...         ...               ...
# 103  362   29      F    American               NaN
# 104  363   22      M    Canadian           Toronto
# 105  364   23      M       Irish           Donegal
# 106  374   28      M  Australian           English
# 107  376   22      M      Indian               NaN
#
# [107 rows x 5 columns]

# %%
vcsk_speakers_grouped = vcsk_speakers.groupby(['GENDER', 'ACCENTS'])['ID'].agg(list)
vcsk_speakers_grouped
# Out:
# GENDER  ACCENTS
# F       American         [294, 297, 299, 300, 301, 305, 306, 308, 310, ...
#         Canadian                                 [303, 307, 312, 317, 343]
#         English          [225, 228, 229, 230, 231, 233, 236, 239, 240, ...
#         Indian                                                       [248]
#         Irish                               [266, 283, 288, 295, 313, 340]
#         NewZealand                                                   [335]
#         NorthernIrish                                 [238, 261, 293, 351]
#         Scottish                                 [234, 249, 262, 264, 265]
#         SouthAfrican                                       [314, 323, 336]
#         Welsh                                                        [253]
# M       American                                      [311, 334, 345, 360]
#         Australian                                              [326, 374]
# ...

# %%
rd.seed(42)
vcsk_speakers_chosen = vcsk_speakers_grouped.loc[(slice(None), ['American', 'English', 'Indian', 'Irish', 'Scottish'])].apply(rd.choice)
vcsk_speakers_chosen = vcsk_speakers_chosen.reset_index()
vcsk_speakers_chosen
# Out:
#   GENDER   ACCENTS   ID
# 0      F  American  300
# 1      F   English  225
# 2      F    Indian  248
# 3      F     Irish  283
# 4      F  Scottish  249
# 5      M  American  334
# 6      M   English  278
# 7      M    Indian  251
# 8      M     Irish  364
# 9      M  Scottish  281

# %%
vcsk_speakers_chosen['speaker_id'] = vcsk_speakers_chosen['ID'].apply(lambda x: f"p{x}")
vcsk_speakers_chosen
# Out:
#   GENDER   ACCENTS   ID speaker_id
# 0      F  American  300       p300
# 1      F   English  225       p225
# 2      F    Indian  248       p248
# 3      F     Irish  283       p283
# 4      F  Scottish  249       p249
# 5      M  American  334       p334
# 6      M   English  278       p278
# 7      M    Indian  251       p251
# 8      M     Irish  364       p364
# 9      M  Scottish  281       p281

# %%
rd.seed(42)
vcsk_wav_chosen = vctk_df.groupby('speaker_id')['audio_id'].agg(list).apply(lambda x: rd.sample(x, 4))
vcsk_wav_chosen = vcsk_wav_chosen.reset_index()
vcsk_wav_chosen
# Out:
#     speaker_id                                           audio_id
# 0         p225  [p225_351.wav, p225_062.wav, p225_016.wav, p22...
# 1         p226  [p226_153.wav, p226_150.wav, p226_116.wav, p22...
# 2         p227  [p227_384.wav, p227_081.wav, p227_392.wav, p22...
# 3         p228  [p228_024.wav, p228_014.wav, p228_063.wav, p22...
# 4         p229  [p229_139.wav, p229_318.wav, p229_012.wav, p22...
# ..         ...                                                ...
# 103       p362  [p362_033.wav, p362_258.wav, p362_106.wav, p36...
# 104       p363  [p363_258.wav, p363_198.wav, p363_188.wav, p36...
# 105       p364  [p364_083.wav, p364_002.wav, p364_202.wav, p36...
# 106       p374  [p374_275.wav, p374_245.wav, p374_198.wav, p37...
# 107       p376  [p376_259.wav, p376_068.wav, p376_106.wav, p37...
#
# [108 rows x 2 columns]

# %%
vctk_cmos = pd.merge(vcsk_speakers_chosen, vcsk_wav_chosen, on='speaker_id')
vctk_cmos
# Out:
#   GENDER   ACCENTS   ID speaker_id  \
# 0      F  American  300       p300
# 1      F   English  225       p225
# 2      F    Indian  248       p248
# 3      F     Irish  283       p283
# 4      F  Scottish  249       p249
# 5      M  American  334       p334
# 6      M   English  278       p278
# 7      M    Indian  251       p251
# 8      M     Irish  364       p364
# 9      M  Scottish  281       p281
#
#                                             audio_id
# 0  [p300_028.wav, p300_381.wav, p300_339.wav, p30...
# 1  [p225_351.wav, p225_062.wav, p225_016.wav, p22...
# 2  [p248_186.wav, p248_034.wav, p248_130.wav, p24...
# 3  [p283_049.wav, p283_422.wav, p283_265.wav, p28...
# 4  [p249_223.wav, p249_276.wav, p249_211.wav, p24...
# 5  [p334_030.wav, p334_018.wav, p334_260.wav, p33...
# 6  [p278_050.wav, p278_404.wav, p278_017.wav, p27...
# 7  [p251_140.wav, p251_345.wav, p251_282.wav, p25...
# 8  [p364_083.wav, p364_002.wav, p364_202.wav, p36...
# ...

# %%
vctk_cmos = vctk_cmos.explode('audio_id').reset_index(drop=True)
vctk_cmos
# Out:
#    GENDER   ACCENTS   ID speaker_id      audio_id
# 0       F  American  300       p300  p300_028.wav
# 1       F  American  300       p300  p300_381.wav
# 2       F  American  300       p300  p300_339.wav
# 3       F  American  300       p300  p300_224.wav
# 4       F   English  225       p225  p225_351.wav
# 5       F   English  225       p225  p225_062.wav
# 6       F   English  225       p225  p225_016.wav
# 7       F   English  225       p225  p225_128.wav
# 8       F    Indian  248       p248  p248_186.wav
# 9       F    Indian  248       p248  p248_034.wav
# 10      F    Indian  248       p248  p248_130.wav
# 11      F    Indian  248       p248  p248_029.wav
# 12      F     Irish  283       p283  p283_049.wav
# 13      F     Irish  283       p283  p283_422.wav
# 14      F     Irish  283       p283  p283_265.wav
# 15      F     Irish  283       p283  p283_226.wav
# 16      F  Scottish  249       p249  p249_223.wav
# 17      F  Scottish  249       p249  p249_276.wav
# ...

# %%
vctk_cmos = pd.merge(vctk_cmos, vctk_df[['audio_id', 'text']], on='audio_id')
vctk_cmos
# Out:
#    GENDER   ACCENTS   ID speaker_id      audio_id  \
# 0       F  American  300       p300  p300_028.wav
# 1       F  American  300       p300  p300_381.wav
# 2       F  American  300       p300  p300_339.wav
# 3       F  American  300       p300  p300_224.wav
# 4       F   English  225       p225  p225_351.wav
# 5       F   English  225       p225  p225_062.wav
# 6       F   English  225       p225  p225_016.wav
# 7       F   English  225       p225  p225_128.wav
# 8       F    Indian  248       p248  p248_186.wav
# 9       F    Indian  248       p248  p248_034.wav
# 10      F    Indian  248       p248  p248_130.wav
# 11      F    Indian  248       p248  p248_029.wav
# 12      F     Irish  283       p283  p283_049.wav
# 13      F     Irish  283       p283  p283_422.wav
# 14      F     Irish  283       p283  p283_265.wav
# 15      F     Irish  283       p283  p283_226.wav
# 16      F  Scottish  249       p249  p249_223.wav
# 17      F  Scottish  249       p249  p249_276.wav
# ...

# %%
vctk_cmos["dataset"] = "vctk"

# %%
vctk_cmos.to_csv('../data/VCTK-Corpus/vctk_cmos.csv', index=False)

# %% [markdown]
# ## LJ

# %%
lj_df = pd.read_csv('../data/keithito_lj_speech/test_metadata.csv')
lj_df
# Out:
#             audio_id                                               text  \
# 0     LJ044-0001.wav  Report of the President's Commission on the As...
# 1     LJ029-0001.wav  Report of the President's Commission on the As...
# 2     LJ037-0001.wav  Report of the President's Commission on the As...
# 3     LJ050-0197.wav                     According to Secretary Dillon,
# 4     LJ043-0002.wav  The Warren Commission Report. By The President...
# ...              ...                                                ...
# 2614  LJ013-0152.wav  at Montreuil. He was arraigned at the Old Bail...
# 2615  LJ045-0052.wav  which Mrs. Paine had made in part to give her ...
# 2616  LJ019-0382.wav  As the years passed, great want of uniformity ...
# 2617  LJ007-0186.wav  the undue authority given to prisoners, the le...
# 2618  LJ036-0082.wav  Craig testified that later in the afternoon he...
#
#       speaker_id                              whisper_transcription
# ...

# %%
lj_df.groupby('text').count().sort_values('audio_id', ascending=False)
# Out:
#                                                     audio_id  speaker_id  \
# text
# And two other justices agreed with him.                    2           2
# Report of the President's Commission on the Ass...         2           2
# The Commission believes, however,                          2           2
# Within a month or two the bank of Messrs. Roger...         1           1
# Within a year he was advanced to the post of ch...         1           1
# ...                                                      ...         ...
# Materials used to make bag.                                1           1
# Matters were on much the same footing at St. Al...         1           1
# May was smuggled in through a window on the esp...         1           1
# McWatters also remembered that a man received a...         1           1
# Marina Oswald testified that the photographs we...         1           1
#
#                                                     whisper_transcription
# text
# ...

# %%
lj_samples_chosen = lj_df[lj_df['text'].apply(lambda x: x[0].isupper() and x[-1] == '.')].sample(4, random_state=42)
lj_samples_chosen
# Out:
#             audio_id                                               text  \
# 2007  LJ016-0139.wav  The last escape from Newgate was only three ye...
# 2176  LJ028-0499.wav  Ctesias mentions three hundred feet; probably ...
# 1571  LJ009-0233.wav  The rope still broke sometimes, although it wa...
# 1097  LJ016-0402.wav  No woman could resist him, he calmly assured M...
#
#       speaker_id                              whisper_transcription
# 2007  lg_speaker   The last escape from Newgate was only three y...
# 2176  lg_speaker   Cessius mentions three hundred feet. Probably...
# 1571  lg_speaker   The rope still broke sometimes, although it w...
# 1097  lg_speaker   No woman could resist him, he calmly assured ...

# %%
lj_cmos = pd.DataFrame({
    'GENDER': ['F']*4,
    'ACCENTS': [None]*4,
    "ID": ['lj']*4,
    "speaker_id": ['lj_speaker']*4,
    "audio_id": lj_samples_chosen["audio_id"].tolist(),
    "text": lj_samples_chosen["text"].tolist(),
    "dataset": ["lj_speech"]*4
})
lj_cmos
# Out:
#   GENDER ACCENTS  ID  speaker_id        audio_id  \
# 0      F    None  lj  lj_speaker  LJ016-0139.wav
# 1      F    None  lj  lj_speaker  LJ028-0499.wav
# 2      F    None  lj  lj_speaker  LJ009-0233.wav
# 3      F    None  lj  lj_speaker  LJ016-0402.wav
#
#                                                 text    dataset
# 0  The last escape from Newgate was only three ye...  lj_speech
# 1  Ctesias mentions three hundred feet; probably ...  lj_speech
# 2  The rope still broke sometimes, although it wa...  lj_speech
# 3  No woman could resist him, he calmly assured M...  lj_speech

# %%
lj_cmos.to_csv('../data/keithito_lj_speech/lj_cmos.csv', index=False)

# %%
cmos_df = pd.concat([vctk_cmos, lj_cmos])
cmos_df
# Out:
#    GENDER   ACCENTS   ID  speaker_id        audio_id  \
# 0       F  American  300        p300    p300_028.wav
# 1       F  American  300        p300    p300_381.wav
# 2       F  American  300        p300    p300_339.wav
# 3       F  American  300        p300    p300_224.wav
# 4       F   English  225        p225    p225_351.wav
# 5       F   English  225        p225    p225_062.wav
# 6       F   English  225        p225    p225_016.wav
# 7       F   English  225        p225    p225_128.wav
# 8       F    Indian  248        p248    p248_186.wav
# 9       F    Indian  248        p248    p248_034.wav
# 10      F    Indian  248        p248    p248_130.wav
# 11      F    Indian  248        p248    p248_029.wav
# 12      F     Irish  283        p283    p283_049.wav
# 13      F     Irish  283        p283    p283_422.wav
# 14      F     Irish  283        p283    p283_265.wav
# 15      F     Irish  283        p283    p283_226.wav
# 16      F  Scottish  249        p249    p249_223.wav
# ...

# %%
cmos_df.to_csv('../data/cmos_speakers.csv', index=False)

# %% [markdown]
# # Calibration samples

# %%
cmos_df = pd.read_csv('../data/cmos_speakers.csv')
cmos_df
# Out:
#    GENDER   ACCENTS   ID  speaker_id        audio_id  \
# 0       F  American  300        p300    p300_028.wav
# 1       F  American  300        p300    p300_381.wav
# 2       F  American  300        p300    p300_339.wav
# 3       F  American  300        p300    p300_224.wav
# 4       F   English  225        p225    p225_351.wav
# 5       F   English  225        p225    p225_062.wav
# 6       F   English  225        p225    p225_016.wav
# 7       F   English  225        p225    p225_128.wav
# 8       F    Indian  248        p248    p248_186.wav
# 9       F    Indian  248        p248    p248_034.wav
# 10      F    Indian  248        p248    p248_130.wav
# 11      F    Indian  248        p248    p248_029.wav
# 12      F     Irish  283        p283    p283_049.wav
# 13      F     Irish  283        p283    p283_422.wav
# 14      F     Irish  283        p283    p283_265.wav
# 15      F     Irish  283        p283    p283_226.wav
# 16      F  Scottish  249        p249    p249_223.wav
# ...

# %%
vctk_df_filtered = vctk_df[~vctk_df['audio_id'].isin(cmos_df['audio_id'])]
vctk_df_filtered
# Out:
#      speaker_id      audio_id  \
# 1          p225  p225_022.wav
# 2          p225  p225_060.wav
# 4          p225  p225_066.wav
# 5          p225  p225_072.wav
# 6          p225  p225_084.wav
# ...         ...           ...
# 4402       p376  p376_259.wav
# 4403       p376  p376_263.wav
# 4404       p376  p376_272.wav
# 4405       p376  p376_284.wav
# 4406       p376  p376_285.wav
#
#                                                    text  \
# 1     The actual primary rainbow observed is said to...
# 2       Strathclyde police have appealed for witnesses.
# 4                          It is a job creation scheme.
# 5                 What kind of man does that, Mr Dick ?
# 6        He is delighted, and he has every right to be.
# ...                                                 ...
# 4402  It is not satisfied with the standard of fire ...
# 4403  Similar measures are expected in England and W...
# 4404                                      Its so awful.
# ...

# %%
rd.seed(42)
vcsk_wav_chosen_calib = vctk_df_filtered.groupby('speaker_id')['audio_id'].agg(list).apply(lambda x: rd.choice(x))
vcsk_wav_chosen_calib = vcsk_wav_chosen_calib.reset_index()
vcsk_wav_chosen_calib
# Out:
#     speaker_id      audio_id
# 0         p225  p225_072.wav
# 1         p226  p226_009.wav
# 2         p227  p227_194.wav
# 3         p228  p228_167.wav
# 4         p229  p229_139.wav
# ..         ...           ...
# 103       p362  p362_075.wav
# 104       p363  p363_115.wav
# 105       p364  p364_292.wav
# 106       p374  p374_372.wav
# 107       p376  p376_225.wav
#
# [108 rows x 2 columns]

# %%
vctk_cmos_calib = pd.merge(vcsk_speakers_chosen, vcsk_wav_chosen_calib, on='speaker_id')
vctk_cmos_calib
# Out:
#   GENDER   ACCENTS   ID speaker_id      audio_id
# 0      F  American  300       p300  p300_263.wav
# 1      F   English  225       p225  p225_072.wav
# 2      F    Indian  248       p248  p248_139.wav
# 3      F     Irish  283       p283  p283_459.wav
# 4      F  Scottish  249       p249  p249_174.wav
# 5      M  American  334       p334  p334_253.wav
# 6      M   English  278       p278  p278_310.wav
# 7      M    Indian  251       p251  p251_190.wav
# 8      M     Irish  364       p364  p364_292.wav
# 9      M  Scottish  281       p281  p281_035.wav

# %%
vctk_cmos_calib = pd.merge(vctk_cmos_calib, vctk_df[['audio_id', 'text']], on='audio_id')
vctk_cmos_calib
# Out:
#   GENDER   ACCENTS   ID speaker_id      audio_id  \
# 0      F  American  300       p300  p300_263.wav
# 1      F   English  225       p225  p225_072.wav
# 2      F    Indian  248       p248  p248_139.wav
# 3      F     Irish  283       p283  p283_459.wav
# 4      F  Scottish  249       p249  p249_174.wav
# 5      M  American  334       p334  p334_253.wav
# 6      M   English  278       p278  p278_310.wav
# 7      M    Indian  251       p251  p251_190.wav
# 8      M     Irish  364       p364  p364_292.wav
# 9      M  Scottish  281       p281  p281_035.wav
#
#                                        text
# 0   That means no more taxation by stealth.
# 1     What kind of man does that, Mr Dick ?
# 2                           It was typical.
# 3              He was confronted by police.
# 4                We have a budget in March.
# 5             Im getting back up there now.
# 6  I couldnt really work outside Edinburgh.
# 7    However, this idea is never developed.
# ...

# %%
lj_df_calib = lj_df[~lj_df['audio_id'].isin(cmos_df['audio_id'])]
lj_df_calib
# Out:
#             audio_id                                               text  \
# 0     LJ044-0001.wav  Report of the President's Commission on the As...
# 1     LJ029-0001.wav  Report of the President's Commission on the As...
# 2     LJ037-0001.wav  Report of the President's Commission on the As...
# 3     LJ050-0197.wav                     According to Secretary Dillon,
# 4     LJ043-0002.wav  The Warren Commission Report. By The President...
# ...              ...                                                ...
# 2614  LJ013-0152.wav  at Montreuil. He was arraigned at the Old Bail...
# 2615  LJ045-0052.wav  which Mrs. Paine had made in part to give her ...
# 2616  LJ019-0382.wav  As the years passed, great want of uniformity ...
# 2617  LJ007-0186.wav  the undue authority given to prisoners, the le...
# 2618  LJ036-0082.wav  Craig testified that later in the afternoon he...
#
#       speaker_id                              whisper_transcription
# ...

# %%
lj_df_calib.sample(1, random_state=42)
# Out:
#             audio_id                                               text  \
# 2602  LJ003-0305.wav  The provision of more baths was also suggested...
#
#       speaker_id                              whisper_transcription
# 2602  lg_speaker   The provision of more baths was also suggeste...

# %%
cmos_calib_df = pd.concat([vctk_cmos_calib[['speaker_id', 'audio_id', 'text']], lj_df_calib.sample(1, random_state=42)[['speaker_id', 'audio_id', 'text']]])
cmos_calib_df
# Out:
#       speaker_id        audio_id  \
# 0           p300    p300_263.wav
# 1           p225    p225_072.wav
# 2           p248    p248_139.wav
# 3           p283    p283_459.wav
# 4           p249    p249_174.wav
# 5           p334    p334_253.wav
# 6           p278    p278_310.wav
# 7           p251    p251_190.wav
# 8           p364    p364_292.wav
# 9           p281    p281_035.wav
# 2602  lg_speaker  LJ003-0305.wav
#
#                                                    text
# 0               That means no more taxation by stealth.
# 1                 What kind of man does that, Mr Dick ?
# 2                                       It was typical.
# 3                          He was confronted by police.
# 4                            We have a budget in March.
# 5                         Im getting back up there now.
# 6              I couldnt really work outside Edinburgh.
# 7                However, this idea is never developed.
# ...

# %%
cmos_calib_df.loc[cmos_calib_df['speaker_id'] == 'lg_speaker', 'speaker_id'] = 'lj_speaker'
cmos_calib_df
# Out:
#       speaker_id        audio_id  \
# 0           p300    p300_263.wav
# 1           p225    p225_072.wav
# 2           p248    p248_139.wav
# 3           p283    p283_459.wav
# 4           p249    p249_174.wav
# 5           p334    p334_253.wav
# 6           p278    p278_310.wav
# 7           p251    p251_190.wav
# 8           p364    p364_292.wav
# 9           p281    p281_035.wav
# 2602  lj_speaker  LJ003-0305.wav
#
#                                                    text
# 0               That means no more taxation by stealth.
# 1                 What kind of man does that, Mr Dick ?
# 2                                       It was typical.
# 3                          He was confronted by police.
# 4                            We have a budget in March.
# 5                         Im getting back up there now.
# 6              I couldnt really work outside Edinburgh.
# 7                However, this idea is never developed.
# ...

# %%
cmos_calib_df.to_csv('../data/cmos_calib_samples.csv', index=False)
